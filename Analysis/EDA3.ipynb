# %%
import pandas  as pd
import numpy as np

# %%
df = pd.read_csv('../data/european_birds.csv')
df.head()
# Out:
#   primary_label secondary_labels                    type  latitude  longitude
# 0        amtspa               []                ['call']   55.6237    13.2427  \
# 1        amtspa               []                ['call']   55.6237    13.2427
# 2        amtspa               []                ['call']   55.6237    13.2427
# 3        banswa               []                ['call']   54.5592    11.9695
# 4        banswa               []  ['alarm call', 'call']   46.1374     5.9609
#
#         scientific_name            common_name        date      filename
# 0  Spizelloides arborea  American Tree Sparrow  2016-11-12  XC342444.ogg  \
# 1  Spizelloides arborea  American Tree Sparrow  2016-11-16  XC342952.ogg
# 2  Spizelloides arborea  American Tree Sparrow  2016-11-16  XC342954.ogg
# 3       Riparia riparia           Bank Swallow  2013-06-08  XC138517.ogg
# 4       Riparia riparia           Bank Swallow  2013-07-13  XC142649.ogg
#
#                                              license  rating   time
# 0  Creative Commons Attribution-NonCommercial-Sha...     2.0  14:00  \
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.0  08:31
# 2  Creative Commons Attribution-NonCommercial-Sha...     4.0  10:28
# 3  Creative Commons Attribution-NonCommercial-Sha...     4.0  05:18
# 4  Creative Commons Attribution-NonCommercial-Sha...     3.5  09:00
#
#                   geometry
# 0  POINT (13.2427 55.6237)
# 1  POINT (13.2427 55.6237)
# 2  POINT (13.2427 55.6237)
# 3  POINT (11.9695 54.5592)
# 4   POINT (5.9609 46.1374)

# %%
unique_common_names = df['common_name'].nunique()
print(f"Number of unique common names: {unique_common_names}")
# Out:
# Number of unique common names: 143

# %%
bird_species = df.groupby('common_name').agg(
    count=('common_name', 'size'),
    scientific_name=('scientific_name', 'first'),
    primary_label=('primary_label', 'first')
).reset_index()

print(bird_species)
bird_species.to_csv('bird_species_summary.csv', index=False)
# Out:
#                common_name  count           scientific_name primary_label
# 0      African Sacred Ibis      2  Threskiornis aethiopicus       sacibi2
# 1    American Tree Sparrow      3      Spizelloides arborea        amtspa
# 2          American Wigeon      1          Mareca americana        amewig
# 3              Arctic Tern    162         Sterna paradisaea        arcter
# 4             Bank Swallow     86           Riparia riparia        banswa
# ..                     ...    ...                       ...           ...
# 138         Willow Warbler    423    Phylloscopus trochilus        wlwwar
# 139         Wilson's Snipe     11        Gallinago delicata       wilsni1
# 140              Wood Duck      3                Aix sponsa        wooduc
# 141         Wood Sandpiper    774           Tringa glareola        woosan
# 142      Zitting Cisticola    360        Cisticola juncidis       zitcis1
#
# [143 rows x 4 columns]

# %% [markdown]
#  Further EDA:
#
#  What calls
#     distribution of calls in species
#
# Clusters of density in places

# %%
import matplotlib.pyplot as plt

bird_species = bird_species.sort_values(by='count', ascending=False)
# Plot the count of all unique common names
plt.figure(figsize=(9, 5))
plt.bar(bird_species['common_name'], bird_species['count'])
plt.xlabel('Common Name')
plt.ylabel('Count')
plt.title('Count of every species in european birds dataset, n=143')
plt.xticks(rotation=90)
plt.show()

# %%
unique_types = df['type'].nunique()
print(f"Number of unique types: {unique_types}")
# Out:
# Number of unique types: 1318

# %%
unique_type = df['type'].unique()
print(unique_type)
# Out:
# ["['call']" "['alarm call', 'call']" "['male', 'song']" ...
#  "['alarm call', 'call', 'various N calls']"
#  "['flight song', 'uncertain']" "['Flight call', 'uncertain']"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26922 entries, 0 to 26921
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primary_label     26922 non-null  object
#  1   secondary_labels  26922 non-null  object
#  2   type              26922 non-null  object
#  3   latitude          26922 non-null  float64
#  4   longitude         26922 non-null  float64
#  5   scientific_name   26922 non-null  object
#  6   common_name       26922 non-null  object
#  7   date              4829 non-null   object
#  8   filename          26922 non-null  object
#  9   license           26922 non-null  object
#  10  rating            26922 non-null  float64
#  11  time              10784 non-null  object
#  12  geometry          26922 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 2.7+ MB

# %%
print(type(df['type'].iloc[0]))
# Out:
# <class 'str'>

# %%
print(df['type'].head())
# Out:
# 0                  ['call']
# 1                  ['call']
# 2                  ['call']
# 3                  ['call']
# 4    ['alarm call', 'call']
# Name: type, dtype: object

# %%
for i, val in enumerate(df['type']):
    try:
        ast.literal_eval(val)
    except Exception as e:
        print(f"Fehler in Zeile {i}: {val} → {e}")
# Out:
# Fehler in Zeile 0: ['call'] → name 'ast' is not defined
# Fehler in Zeile 1: ['call'] → name 'ast' is not defined
# Fehler in Zeile 2: ['call'] → name 'ast' is not defined
# Fehler in Zeile 3: ['call'] → name 'ast' is not defined
# Fehler in Zeile 4: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 5: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 6: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 7: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 8: ['call'] → name 'ast' is not defined
# Fehler in Zeile 9: ['call'] → name 'ast' is not defined
# Fehler in Zeile 10: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 11: ['begging call', 'call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 12: ['call'] → name 'ast' is not defined
# Fehler in Zeile 13: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 14: ['song'] → name 'ast' is not defined
# Fehler in Zeile 15: ['call'] → name 'ast' is not defined
# Fehler in Zeile 16: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 17: ['song'] → name 'ast' is not defined
# Fehler in Zeile 18: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 19: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 20: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 21: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 22: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 23: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 24: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 25: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26: ['female', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 27: ['call'] → name 'ast' is not defined
# Fehler in Zeile 28: ['call'] → name 'ast' is not defined
# Fehler in Zeile 29: ['call'] → name 'ast' is not defined
# Fehler in Zeile 30: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 31: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 32: ['call'] → name 'ast' is not defined
# Fehler in Zeile 33: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 34: ['call'] → name 'ast' is not defined
# Fehler in Zeile 35: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 36: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 37: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 38: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 39: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 40: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 41: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 42: ['call'] → name 'ast' is not defined
# Fehler in Zeile 43: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 44: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 45: ['call'] → name 'ast' is not defined
# Fehler in Zeile 46: ['call'] → name 'ast' is not defined
# Fehler in Zeile 47: ['call'] → name 'ast' is not defined
# Fehler in Zeile 48: ['call'] → name 'ast' is not defined
# Fehler in Zeile 49: ['call'] → name 'ast' is not defined
# Fehler in Zeile 50: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 51: ['call'] → name 'ast' is not defined
# Fehler in Zeile 52: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 53: ['call'] → name 'ast' is not defined
# Fehler in Zeile 54: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 55: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 56: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 57: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 58: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 59: ['call'] → name 'ast' is not defined
# Fehler in Zeile 60: ['song'] → name 'ast' is not defined
# Fehler in Zeile 61: ['call'] → name 'ast' is not defined
# Fehler in Zeile 62: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 63: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 64: ['call', 'flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 65: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 66: ['adult', 'alarm call', 'call', 'female', 'male'] → name 'ast' is not defined
# Fehler in Zeile 67: ['call'] → name 'ast' is not defined
# Fehler in Zeile 68: ['song'] → name 'ast' is not defined
# Fehler in Zeile 69: ['calls in flight'] → name 'ast' is not defined
# Fehler in Zeile 70: ['adult', 'flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 71: ['adult', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 72: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 73: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 74: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 75: ['flight call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 76: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 77: ['adult', 'call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 78: ['alarm call', 'call', 'flight call', 'various calls'] → name 'ast' is not defined
# Fehler in Zeile 79: ['"djirr"', '"prrt"', 'alarm call', 'call', 'flight call', 'various calls'] → name 'ast' is not defined
# Fehler in Zeile 80: ['"djirr"', '"prrt"', 'alarm call', 'call', 'flight call', 'various calls'] → name 'ast' is not defined
# Fehler in Zeile 81: ['adult', 'alarm call', 'female', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 82: ['adult', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 83: ['adult', 'alarm call', 'female', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 84: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 85: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 86: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 87: ['flight call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 88: ['calls around colony entrance holes', 'call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 89: ['song'] → name 'ast' is not defined
# Fehler in Zeile 90: ['song'] → name 'ast' is not defined
# Fehler in Zeile 91: ['song'] → name 'ast' is not defined
# Fehler in Zeile 92: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 93: ['song'] → name 'ast' is not defined
# Fehler in Zeile 94: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 95: ['song'] → name 'ast' is not defined
# Fehler in Zeile 96: ['begging call', 'call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 97: ['song'] → name 'ast' is not defined
# Fehler in Zeile 98: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 99: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 100: ['begging calls'] → name 'ast' is not defined
# Fehler in Zeile 101: ['song'] → name 'ast' is not defined
# Fehler in Zeile 102: ['song'] → name 'ast' is not defined
# Fehler in Zeile 103: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 104: ['call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 105: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 106: ['song'] → name 'ast' is not defined
# Fehler in Zeile 107: ['call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 108: ['call', 'female', 'male'] → name 'ast' is not defined
# Fehler in Zeile 109: ['song'] → name 'ast' is not defined
# Fehler in Zeile 110: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 111: ['song'] → name 'ast' is not defined
# Fehler in Zeile 112: ['begging call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 113: ['song'] → name 'ast' is not defined
# Fehler in Zeile 114: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 115: ['song'] → name 'ast' is not defined
# Fehler in Zeile 116: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 117: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 118: ['song'] → name 'ast' is not defined
# Fehler in Zeile 119: ['song'] → name 'ast' is not defined
# Fehler in Zeile 120: ['song'] → name 'ast' is not defined
# Fehler in Zeile 121: ['song'] → name 'ast' is not defined
# Fehler in Zeile 122: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 123: ['song'] → name 'ast' is not defined
# Fehler in Zeile 124: ['song'] → name 'ast' is not defined
# Fehler in Zeile 125: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 126: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 127: ['call'] → name 'ast' is not defined
# Fehler in Zeile 128: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 129: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 130: ['begging call', 'feeding sounds'] → name 'ast' is not defined
# Fehler in Zeile 131: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 132: ['song'] → name 'ast' is not defined
# Fehler in Zeile 133: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 134: ['song'] → name 'ast' is not defined
# Fehler in Zeile 135: ['begging call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 136: ['alarm call', 'call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 137: ['song'] → name 'ast' is not defined
# Fehler in Zeile 138: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 139: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 140: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 141: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 142: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 143: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 144: ['begging call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 145: ['song'] → name 'ast' is not defined
# Fehler in Zeile 146: ['call'] → name 'ast' is not defined
# Fehler in Zeile 147: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 148: ['song'] → name 'ast' is not defined
# Fehler in Zeile 149: ['song'] → name 'ast' is not defined
# Fehler in Zeile 150: ['call'] → name 'ast' is not defined
# Fehler in Zeile 151: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 152: ['song'] → name 'ast' is not defined
# Fehler in Zeile 153: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 154: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 155: ['song'] → name 'ast' is not defined
# Fehler in Zeile 156: ['male'] → name 'ast' is not defined
# Fehler in Zeile 157: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 158: ['call'] → name 'ast' is not defined
# Fehler in Zeile 159: ['song'] → name 'ast' is not defined
# Fehler in Zeile 160: ['song'] → name 'ast' is not defined
# Fehler in Zeile 161: ['song'] → name 'ast' is not defined
# Fehler in Zeile 162: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 163: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 164: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 165: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 166: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 167: ['song'] → name 'ast' is not defined
# Fehler in Zeile 168: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 169: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 170: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 171: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 172: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 173: ['call'] → name 'ast' is not defined
# Fehler in Zeile 174: ['song'] → name 'ast' is not defined
# Fehler in Zeile 175: ['song'] → name 'ast' is not defined
# Fehler in Zeile 176: ['song'] → name 'ast' is not defined
# Fehler in Zeile 177: ['call'] → name 'ast' is not defined
# Fehler in Zeile 178: ['song'] → name 'ast' is not defined
# Fehler in Zeile 179: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 180: ['call'] → name 'ast' is not defined
# Fehler in Zeile 181: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 182: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 183: ['song'] → name 'ast' is not defined
# Fehler in Zeile 184: ['call'] → name 'ast' is not defined
# Fehler in Zeile 185: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 186: ['song'] → name 'ast' is not defined
# Fehler in Zeile 187: ['call'] → name 'ast' is not defined
# Fehler in Zeile 188: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 189: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 190: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 191: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 192: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 193: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 194: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 195: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 196: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 197: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 198: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 199: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 200: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 201: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 202: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 203: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 204: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 205: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 206: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 207: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 208: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 209: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 210: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 211: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 212: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 213: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 214: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 215: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 216: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 217: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 218: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 219: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 220: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 221: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 222: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 223: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 224: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 225: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 226: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 227: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 228: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 229: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 230: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 231: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 232: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 233: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 234: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 235: ['call', 'female', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 236: ['flight call', 'male', 'song', 'wingsong'] → name 'ast' is not defined
# Fehler in Zeile 237: ['song'] → name 'ast' is not defined
# Fehler in Zeile 238: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 239: ['song'] → name 'ast' is not defined
# Fehler in Zeile 240: ['song'] → name 'ast' is not defined
# Fehler in Zeile 241: ['song'] → name 'ast' is not defined
# Fehler in Zeile 242: ['song'] → name 'ast' is not defined
# Fehler in Zeile 243: ['song'] → name 'ast' is not defined
# Fehler in Zeile 244: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 245: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 246: ['song'] → name 'ast' is not defined
# Fehler in Zeile 247: ['song'] → name 'ast' is not defined
# Fehler in Zeile 248: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 249: ['song'] → name 'ast' is not defined
# Fehler in Zeile 250: ['song'] → name 'ast' is not defined
# Fehler in Zeile 251: ['song'] → name 'ast' is not defined
# Fehler in Zeile 252: ['song'] → name 'ast' is not defined
# Fehler in Zeile 253: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 254: ['song'] → name 'ast' is not defined
# Fehler in Zeile 255: ['song'] → name 'ast' is not defined
# Fehler in Zeile 256: ['song'] → name 'ast' is not defined
# Fehler in Zeile 257: ['song'] → name 'ast' is not defined
# Fehler in Zeile 258: ['song'] → name 'ast' is not defined
# Fehler in Zeile 259: ['call', 'female', 'juvenile', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 260: ['song'] → name 'ast' is not defined
# Fehler in Zeile 261: ['song'] → name 'ast' is not defined
# Fehler in Zeile 262: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 263: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 264: ['call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 265: ['call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 266: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 267: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 268: ['call', 'flight call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 269: ['begging call', 'call', 'juvenile', 'wing beat'] → name 'ast' is not defined
# Fehler in Zeile 270: ['song'] → name 'ast' is not defined
# Fehler in Zeile 271: ['begging call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 272: ['song'] → name 'ast' is not defined
# Fehler in Zeile 273: ['song'] → name 'ast' is not defined
# Fehler in Zeile 274: ['song'] → name 'ast' is not defined
# Fehler in Zeile 275: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 276: ['song'] → name 'ast' is not defined
# Fehler in Zeile 277: ['song'] → name 'ast' is not defined
# Fehler in Zeile 278: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 279: ['song'] → name 'ast' is not defined
# Fehler in Zeile 280: ['song'] → name 'ast' is not defined
# Fehler in Zeile 281: ['call'] → name 'ast' is not defined
# Fehler in Zeile 282: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 283: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 284: ['begging call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 285: ['song'] → name 'ast' is not defined
# Fehler in Zeile 286: ['call'] → name 'ast' is not defined
# Fehler in Zeile 287: ['begging call', 'call', 'female', 'juvenile', 'male'] → name 'ast' is not defined
# Fehler in Zeile 288: ['i think it is a song', 'song'] → name 'ast' is not defined
# Fehler in Zeile 289: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 290: ['song'] → name 'ast' is not defined
# Fehler in Zeile 291: ['adults feeding babies'] → name 'ast' is not defined
# Fehler in Zeile 292: ['adult feeding babies'] → name 'ast' is not defined
# Fehler in Zeile 293: ['call'] → name 'ast' is not defined
# Fehler in Zeile 294: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 295: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 296: ['song'] → name 'ast' is not defined
# Fehler in Zeile 297: ['call'] → name 'ast' is not defined
# Fehler in Zeile 298: ['song'] → name 'ast' is not defined
# Fehler in Zeile 299: ['song'] → name 'ast' is not defined
# Fehler in Zeile 300: ['call'] → name 'ast' is not defined
# Fehler in Zeile 301: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 302: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 303: ['song'] → name 'ast' is not defined
# Fehler in Zeile 304: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 305: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 306: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 307: ['song'] → name 'ast' is not defined
# Fehler in Zeile 308: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 309: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 310: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 311: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 312: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 313: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 314: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 315: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 316: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 317: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 318: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 319: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 320: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 321: ['song'] → name 'ast' is not defined
# Fehler in Zeile 322: ['flight call', 'nocturnal  flight call'] → name 'ast' is not defined
# Fehler in Zeile 323: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 324: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 325: ['alarm call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 326: ['alarm call', 'call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 327: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 328: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 329: ['call'] → name 'ast' is not defined
# Fehler in Zeile 330: ['call'] → name 'ast' is not defined
# Fehler in Zeile 331: ['juvenile'] → name 'ast' is not defined
# Fehler in Zeile 332: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 333: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 334: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 335: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 336: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 337: ['adult', 'anxiety call', 'call'] → name 'ast' is not defined
# Fehler in Zeile 338: ['adult', 'song'] → name 'ast' is not defined
# Fehler in Zeile 339: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 340: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 341: ['song'] → name 'ast' is not defined
# Fehler in Zeile 342: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 343: ['call'] → name 'ast' is not defined
# Fehler in Zeile 344: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 345: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 346: ['call'] → name 'ast' is not defined
# Fehler in Zeile 347: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 348: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 349: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 350: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 351: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 352: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 353: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 354: ['song'] → name 'ast' is not defined
# Fehler in Zeile 355: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 356: ['song'] → name 'ast' is not defined
# Fehler in Zeile 357: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 358: ['subsong'] → name 'ast' is not defined
# Fehler in Zeile 359: ['song'] → name 'ast' is not defined
# Fehler in Zeile 360: ['song'] → name 'ast' is not defined
# Fehler in Zeile 361: ['song'] → name 'ast' is not defined
# Fehler in Zeile 362: ['call'] → name 'ast' is not defined
# Fehler in Zeile 363: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 364: ['song'] → name 'ast' is not defined
# Fehler in Zeile 365: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 366: ['song'] → name 'ast' is not defined
# Fehler in Zeile 367: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 368: ['call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 369: ['adult', 'call', 'juvenile', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 370: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 371: ['song'] → name 'ast' is not defined
# Fehler in Zeile 372: ['call', 'song', 'various calls'] → name 'ast' is not defined
# Fehler in Zeile 373: ['call', 'song', 'various calls'] → name 'ast' is not defined
# Fehler in Zeile 374: ['call'] → name 'ast' is not defined
# Fehler in Zeile 375: ['call'] → name 'ast' is not defined
# Fehler in Zeile 376: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 377: ['song'] → name 'ast' is not defined
# Fehler in Zeile 378: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 379: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 380: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 381: ['adult', 'song'] → name 'ast' is not defined
# Fehler in Zeile 382: ['call', 'juvenile', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 383: ['uncertain'] → name 'ast' is not defined
# Fehler in Zeile 384: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 385: ['uncertain'] → name 'ast' is not defined
# Fehler in Zeile 386: ['song'] → name 'ast' is not defined
# Fehler in Zeile 387: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 388: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 389: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 390: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 391: ['alarm call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 392: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 393: ['flight call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 394: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 395: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 396: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 397: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 398: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 399: ['adult', 'call', 'flight call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 400: ['flight call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 401: ['call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 402: ['call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 403: ['call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 404: ['adult', 'begging call', 'call', 'juvenile', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 405: ['adult', 'call', 'juvenile', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 406: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 407: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 408: ['call'] → name 'ast' is not defined
# Fehler in Zeile 409: ['adult', 'sex uncertain', 'song'] → name 'ast' is not defined
# Fehler in Zeile 410: ['adult', 'call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 411: ['adult', 'alarm call', 'call', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 412: ['song'] → name 'ast' is not defined
# Fehler in Zeile 413: ['song'] → name 'ast' is not defined
# Fehler in Zeile 414: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 415: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 416: ['call'] → name 'ast' is not defined
# Fehler in Zeile 417: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 418: ['call'] → name 'ast' is not defined
# Fehler in Zeile 419: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 420: ['call'] → name 'ast' is not defined
# Fehler in Zeile 421: ['call'] → name 'ast' is not defined
# Fehler in Zeile 422: ['begging call'] → name 'ast' is not defined
# Fehler in Zeile 423: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 424: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 425: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 426: ['call', 'female', 'male'] → name 'ast' is not defined
# Fehler in Zeile 427: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 428: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 429: ['call'] → name 'ast' is not defined
# Fehler in Zeile 430: ['call'] → name 'ast' is not defined
# Fehler in Zeile 431: ['call'] → name 'ast' is not defined
# Fehler in Zeile 432: ['call'] → name 'ast' is not defined
# Fehler in Zeile 433: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 434: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 435: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 436: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 437: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 438: ['begging call', 'call', 'chicks and adult in breeding colony', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 439: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 440: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 441: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 442: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 443: ['call'] → name 'ast' is not defined
# Fehler in Zeile 444: ['flight call', 'nocturnal flightcall'] → name 'ast' is not defined
# Fehler in Zeile 445: ['call'] → name 'ast' is not defined
# Fehler in Zeile 446: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 447: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 448: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 449: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 450: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 451: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 452: ['call', 'female', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 453: ['nocturnal flight call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 454: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 455: ['flight call', 'nocturnal flightcall'] → name 'ast' is not defined
# Fehler in Zeile 456: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 457: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 458: ['flight call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 459: ['begging call', 'call', 'juvenile'] → name 'ast' is not defined
# Fehler in Zeile 460: ['nocturnal flight call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 461: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 462: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 463: ['call'] → name 'ast' is not defined
# Fehler in Zeile 464: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 465: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 466: ['nfc', 'nocturnal flight call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 467: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 468: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 469: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 470: ['flight call', 'nocturnal'] → name 'ast' is not defined
# Fehler in Zeile 471: ['flight call', 'nocturnal'] → name 'ast' is not defined
# Fehler in Zeile 472: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 473: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 474: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 475: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 476: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 477: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 478: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 479: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 480: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 481: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 482: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 483: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 484: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 485: ['flight call', 'night flight call'] → name 'ast' is not defined
# Fehler in Zeile 486: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 487: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 488: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 489: ['call'] → name 'ast' is not defined
# Fehler in Zeile 490: ['flight call', 'night flight call'] → name 'ast' is not defined
# Fehler in Zeile 491: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 492: ['call'] → name 'ast' is not defined
# Fehler in Zeile 493: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 494: ['call'] → name 'ast' is not defined
# Fehler in Zeile 495: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 496: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 497: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 498: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 499: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 500: ['nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 501: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 502: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 503: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 504: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 505: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 506: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 507: ['nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 508: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 509: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 510: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 511: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 512: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 513: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 514: ['call', 'flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 515: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 516: ['call', 'flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 517: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 518: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 519: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 520: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 521: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 522: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 523: ['nocturnal flight call', 'wings beats'] → name 'ast' is not defined
# Fehler in Zeile 524: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 525: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 526: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 527: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 528: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 529: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 530: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 531: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 532: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 533: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 534: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 535: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 536: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 537: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 538: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 539: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 540: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 541: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 542: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 543: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 544: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 545: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 546: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 547: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 548: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 549: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 550: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 551: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 552: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 553: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 554: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 555: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 556: ['life stage uncertain', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 557: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 558: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 559: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 560: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 561: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 562: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 563: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 564: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 565: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 566: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 567: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 568: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 569: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 570: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 571: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 572: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 573: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 574: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 575: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 576: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 577: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 578: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 579: ['flight call', 'human voices', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 580: ['adult', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 581: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 582: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 583: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 584: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 585: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 586: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 587: ['uncertain'] → name 'ast' is not defined
# Fehler in Zeile 588: ['adult', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 589: ['adult', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 590: ['begging call', 'hatchling or nestling', 'juvenile', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 591: ['adult', 'call', 'female', 'flight call', 'juvenile', 'male', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 592: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 593: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 594: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 595: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 596: ['juvenile', 'nocturnal flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 597: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 598: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 599: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 600: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 601: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 602: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 603: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 604: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 605: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 606: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 607: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 608: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 609: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 610: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 611: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 612: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 613: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 614: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 615: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 616: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 617: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 618: ['uncertain'] → name 'ast' is not defined
# Fehler in Zeile 619: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 620: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 621: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 622: ['flight call', 'nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 623: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 624: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 625: ['adult', 'flight call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 626: ['adult', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 627: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 628: ['nocturnal flight call'] → name 'ast' is not defined
# Fehler in Zeile 629: ['call'] → name 'ast' is not defined
# Fehler in Zeile 630: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 631: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 632: ['call'] → name 'ast' is not defined
# Fehler in Zeile 633: ['call'] → name 'ast' is not defined
# Fehler in Zeile 634: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 635: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 636: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 637: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 638: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 639: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 640: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 641: ['call'] → name 'ast' is not defined
# Fehler in Zeile 642: ['call'] → name 'ast' is not defined
# Fehler in Zeile 643: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 644: ['call'] → name 'ast' is not defined
# Fehler in Zeile 645: ['call'] → name 'ast' is not defined
# Fehler in Zeile 646: ['call'] → name 'ast' is not defined
# Fehler in Zeile 647: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 648: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 649: ['call', 'flight call', 'migrating birds flying over'] → name 'ast' is not defined
# Fehler in Zeile 650: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 651: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 652: ['call'] → name 'ast' is not defined
# Fehler in Zeile 653: ['call'] → name 'ast' is not defined
# Fehler in Zeile 654: ['call'] → name 'ast' is not defined
# Fehler in Zeile 655: ['call'] → name 'ast' is not defined
# Fehler in Zeile 656: ['call'] → name 'ast' is not defined
# Fehler in Zeile 657: ['call'] → name 'ast' is not defined
# Fehler in Zeile 658: ['call'] → name 'ast' is not defined
# Fehler in Zeile 659: ['song'] → name 'ast' is not defined
# Fehler in Zeile 660: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 661: ['call'] → name 'ast' is not defined
# ...
# Fehler in Zeile 26672: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26673: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26674: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26675: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26676: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26677: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26678: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26679: ['Male', 'song', 'sound'] → name 'ast' is not defined
# Fehler in Zeile 26680: ['Flight song'] → name 'ast' is not defined
# Fehler in Zeile 26681: ['Flight song'] → name 'ast' is not defined
# Fehler in Zeile 26682: ['conflict song in flight', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26683: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26684: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26685: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26686: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26687: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26688: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26689: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26690: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26691: ['Flight song'] → name 'ast' is not defined
# Fehler in Zeile 26692: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26693: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26694: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26695: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26696: ['alarm call', 'call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26697: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26698: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26699: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26700: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26701: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26702: ['Flight song'] → name 'ast' is not defined
# Fehler in Zeile 26703: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26704: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26705: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26706: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26707: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26708: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26709: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 26710: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26711: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26712: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26713: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 26714: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26715: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26716: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26717: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26718: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26719: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26720: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26721: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26722: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26723: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26724: ['call', 'flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26725: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26726: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26727: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26728: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26729: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26730: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26731: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26732: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26733: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26734: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26735: ['flight', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26736: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26737: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26738: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26739: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26740: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26741: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26742: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26743: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26744: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26745: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26746: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26747: ['adult', 'flight call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26748: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26749: ['adult', 'alarm call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26750: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26751: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26752: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26753: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26754: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26755: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26756: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26757: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26758: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26759: ['alarm call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26760: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26761: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26762: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26763: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26764: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26765: ['song', 'song in flight'] → name 'ast' is not defined
# Fehler in Zeile 26766: ['song', 'song in flight'] → name 'ast' is not defined
# Fehler in Zeile 26767: ['song', 'song in flight'] → name 'ast' is not defined
# Fehler in Zeile 26768: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26769: ['call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26770: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26771: ['call', 'two differnt calls'] → name 'ast' is not defined
# Fehler in Zeile 26772: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26773: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26774: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26775: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26776: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26777: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26778: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26779: ['alarm call from a juvenile perched on a reed', 'an adult flying over it'] → name 'ast' is not defined
# Fehler in Zeile 26780: ['call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26781: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26782: ['call', 'life stage uncertain', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26783: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26784: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26785: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26786: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26787: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26788: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26789: ['alarm call', 'call', 'metallic alarm'] → name 'ast' is not defined
# Fehler in Zeile 26790: ['alarm call', 'call', 'various N calls'] → name 'ast' is not defined
# Fehler in Zeile 26791: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26792: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26793: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26794: ['call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26795: ['flight call', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26796: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26797: ['adult', 'call', 'flight call'] → name 'ast' is not defined
# Fehler in Zeile 26798: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26799: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26800: ['adult', 'flight call', 'male'] → name 'ast' is not defined
# Fehler in Zeile 26801: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26802: ['flight song', 'uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26803: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26804: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26805: ['adult', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26806: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26807: ['Flight call', 'uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26808: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26809: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26810: ['male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26811: ['adult', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26812: ['song'] → name 'ast' is not defined
# Fehler in Zeile 26813: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26814: ['flight call'] → name 'ast' is not defined
# Fehler in Zeile 26815: ['adult', 'alarm call', 'call', 'male', 'song'] → name 'ast' is not defined
# Fehler in Zeile 26816: ['call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26817: ['alarm call', 'sex uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26818: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26819: ['call'] → name 'ast' is not defined
# Fehler in Zeile 26820: ['alarm call'] → name 'ast' is not defined
# Fehler in Zeile 26821: ['call', 'life stage uncertain'] → name 'ast' is not defined
# Fehler in Zeile 26822: [''] → name 'ast' is not defined
# Fehler in Zeile 26823: [''] → name 'ast' is not defined
# Fehler in Zeile 26824: [''] → name 'ast' is not defined
# Fehler in Zeile 26825: [''] → name 'ast' is not defined
# Fehler in Zeile 26826: [''] → name 'ast' is not defined
# Fehler in Zeile 26827: [''] → name 'ast' is not defined
# Fehler in Zeile 26828: [''] → name 'ast' is not defined
# Fehler in Zeile 26829: [''] → name 'ast' is not defined
# Fehler in Zeile 26830: [''] → name 'ast' is not defined
# Fehler in Zeile 26831: [''] → name 'ast' is not defined
# Fehler in Zeile 26832: [''] → name 'ast' is not defined
# Fehler in Zeile 26833: [''] → name 'ast' is not defined
# Fehler in Zeile 26834: [''] → name 'ast' is not defined
# Fehler in Zeile 26835: [''] → name 'ast' is not defined
# Fehler in Zeile 26836: [''] → name 'ast' is not defined
# Fehler in Zeile 26837: [''] → name 'ast' is not defined
# Fehler in Zeile 26838: [''] → name 'ast' is not defined
# Fehler in Zeile 26839: [''] → name 'ast' is not defined
# Fehler in Zeile 26840: [''] → name 'ast' is not defined
# Fehler in Zeile 26841: [''] → name 'ast' is not defined
# Fehler in Zeile 26842: [''] → name 'ast' is not defined
# Fehler in Zeile 26843: [''] → name 'ast' is not defined
# Fehler in Zeile 26844: [''] → name 'ast' is not defined
# Fehler in Zeile 26845: [''] → name 'ast' is not defined
# Fehler in Zeile 26846: [''] → name 'ast' is not defined
# Fehler in Zeile 26847: [''] → name 'ast' is not defined
# Fehler in Zeile 26848: [''] → name 'ast' is not defined
# Fehler in Zeile 26849: [''] → name 'ast' is not defined
# Fehler in Zeile 26850: [''] → name 'ast' is not defined
# Fehler in Zeile 26851: [''] → name 'ast' is not defined
# Fehler in Zeile 26852: [''] → name 'ast' is not defined
# Fehler in Zeile 26853: [''] → name 'ast' is not defined
# Fehler in Zeile 26854: [''] → name 'ast' is not defined
# Fehler in Zeile 26855: [''] → name 'ast' is not defined
# Fehler in Zeile 26856: [''] → name 'ast' is not defined
# Fehler in Zeile 26857: [''] → name 'ast' is not defined
# Fehler in Zeile 26858: [''] → name 'ast' is not defined
# Fehler in Zeile 26859: [''] → name 'ast' is not defined
# Fehler in Zeile 26860: [''] → name 'ast' is not defined
# Fehler in Zeile 26861: [''] → name 'ast' is not defined
# Fehler in Zeile 26862: [''] → name 'ast' is not defined
# Fehler in Zeile 26863: [''] → name 'ast' is not defined
# Fehler in Zeile 26864: [''] → name 'ast' is not defined
# Fehler in Zeile 26865: [''] → name 'ast' is not defined
# Fehler in Zeile 26866: [''] → name 'ast' is not defined
# Fehler in Zeile 26867: [''] → name 'ast' is not defined
# Fehler in Zeile 26868: [''] → name 'ast' is not defined
# Fehler in Zeile 26869: [''] → name 'ast' is not defined
# Fehler in Zeile 26870: [''] → name 'ast' is not defined
# Fehler in Zeile 26871: [''] → name 'ast' is not defined
# Fehler in Zeile 26872: [''] → name 'ast' is not defined
# Fehler in Zeile 26873: [''] → name 'ast' is not defined
# Fehler in Zeile 26874: [''] → name 'ast' is not defined
# Fehler in Zeile 26875: [''] → name 'ast' is not defined
# Fehler in Zeile 26876: [''] → name 'ast' is not defined
# Fehler in Zeile 26877: [''] → name 'ast' is not defined
# Fehler in Zeile 26878: [''] → name 'ast' is not defined
# Fehler in Zeile 26879: [''] → name 'ast' is not defined
# Fehler in Zeile 26880: [''] → name 'ast' is not defined
# Fehler in Zeile 26881: [''] → name 'ast' is not defined
# Fehler in Zeile 26882: [''] → name 'ast' is not defined
# Fehler in Zeile 26883: [''] → name 'ast' is not defined
# Fehler in Zeile 26884: [''] → name 'ast' is not defined
# Fehler in Zeile 26885: [''] → name 'ast' is not defined
# Fehler in Zeile 26886: [''] → name 'ast' is not defined
# Fehler in Zeile 26887: [''] → name 'ast' is not defined
# Fehler in Zeile 26888: [''] → name 'ast' is not defined
# Fehler in Zeile 26889: [''] → name 'ast' is not defined
# Fehler in Zeile 26890: [''] → name 'ast' is not defined
# Fehler in Zeile 26891: [''] → name 'ast' is not defined
# Fehler in Zeile 26892: [''] → name 'ast' is not defined
# Fehler in Zeile 26893: [''] → name 'ast' is not defined
# Fehler in Zeile 26894: [''] → name 'ast' is not defined
# Fehler in Zeile 26895: [''] → name 'ast' is not defined
# Fehler in Zeile 26896: [''] → name 'ast' is not defined
# Fehler in Zeile 26897: [''] → name 'ast' is not defined
# Fehler in Zeile 26898: [''] → name 'ast' is not defined
# Fehler in Zeile 26899: [''] → name 'ast' is not defined
# Fehler in Zeile 26900: [''] → name 'ast' is not defined
# Fehler in Zeile 26901: [''] → name 'ast' is not defined
# Fehler in Zeile 26902: [''] → name 'ast' is not defined
# Fehler in Zeile 26903: [''] → name 'ast' is not defined
# Fehler in Zeile 26904: [''] → name 'ast' is not defined
# Fehler in Zeile 26905: [''] → name 'ast' is not defined
# Fehler in Zeile 26906: [''] → name 'ast' is not defined
# Fehler in Zeile 26907: [''] → name 'ast' is not defined
# Fehler in Zeile 26908: [''] → name 'ast' is not defined
# Fehler in Zeile 26909: [''] → name 'ast' is not defined
# Fehler in Zeile 26910: [''] → name 'ast' is not defined
# Fehler in Zeile 26911: [''] → name 'ast' is not defined
# Fehler in Zeile 26912: [''] → name 'ast' is not defined
# Fehler in Zeile 26913: [''] → name 'ast' is not defined
# Fehler in Zeile 26914: [''] → name 'ast' is not defined
# Fehler in Zeile 26915: [''] → name 'ast' is not defined
# Fehler in Zeile 26916: [''] → name 'ast' is not defined
# Fehler in Zeile 26917: [''] → name 'ast' is not defined
# Fehler in Zeile 26918: [''] → name 'ast' is not defined
# Fehler in Zeile 26919: [''] → name 'ast' is not defined
# Fehler in Zeile 26920: [''] → name 'ast' is not defined
# Fehler in Zeile 26921: [''] → name 'ast' is not defined

# %%
import json

def safe_list_conversion(value):
    if isinstance(value, list):  
        return value  # Falls es schon eine Liste ist, unverändert zurückgeben
    try:
        return json.loads(value.replace("'", '"'))  # Falls es ein String ist, zu einer Liste konvertieren
    except Exception:
        return []  # Falls ein Fehler auftritt, eine leere Liste zurückgeben

df['type'] = df['type'].apply(safe_list_conversion)

# %%
print(type(df['type'].iloc[0]))  # Sollte nun <class 'list'> ausgeben
print(df['type'].head())  # Sollte echte Listen anzeigen
# Out:
# <class 'list'>
# 0                [call]
# 1                [call]
# 2                [call]
# 3                [call]
# 4    [alarm call, call]
# Name: type, dtype: object

# %%
import ast

# Spalten in Listen umwandeln und explodieren
df_exploded = df.explode('type')

# NaN-Werte in der 'type'-Spalte durch leere Strings ersetzen
df_exploded['type'] = df_exploded['type'].fillna('')

# Nur "Call"-Arten behalten
df_calls = df_exploded[df_exploded['type'].str.contains('call', case=False, regex=True)]

# Gruppieren und zählen
call_distribution_detailed = df_calls.groupby(['common_name', 'type']).size().reset_index(name='count')

print(call_distribution_detailed)
# Out:
#                common_name                                          type
# 0      African Sacred Ibis                                  begging call  \
# 1    American Tree Sparrow                                          call
# 2          American Wigeon                                          call
# 3              Arctic Tern                                    Alarmcalls
# 4              Arctic Tern                                          Call
# ..                     ...                                           ...
# 858      Zitting Cisticola  alarm call from a juvenile perched on a reed
# 859      Zitting Cisticola                                          call
# 860      Zitting Cisticola                                   flight call
# 861      Zitting Cisticola                            two differnt calls
# 862      Zitting Cisticola                               various N calls
#
#      count
# 0        1
# 1        3
# 2        1
# 3        1
# 4        1
# ..     ...
# 858      1
# 859     88
# 860     64
# 861      1
# 862      1
#
# [863 rows x 3 columns]

# %%
call_distribution_detailed.to_csv('call_distribution.csv', index=False)

# %%
call_distribution_detailed.tail()
# Out:
#            common_name                                          type  count
# 858  Zitting Cisticola  alarm call from a juvenile perched on a reed      1
# 859  Zitting Cisticola                                          call     88
# 860  Zitting Cisticola                                   flight call     64
# 861  Zitting Cisticola                            two differnt calls      1
# 862  Zitting Cisticola                               various N calls      1

# %%
unique_common_names_in_calls = call_distribution_detailed['common_name'].nunique()
print(f"Number of unique common names in call_distribution_detailed: {unique_common_names_in_calls}")
# Out:
# Number of unique common names in call_distribution_detailed: 134

# %%
# Sort the dataframe by 'count' in descending order and display the top rows
top_call_counts = call_distribution_detailed.sort_values(by='count', ascending=False).head(10)
print(top_call_counts)
# Out:
#                    common_name                   type  count
# 515              House Sparrow                   call    732
# 241           Common Sandpiper  nocturnal flight call    632
# 76   Black-crowned Night-Heron  nocturnal flight call    489
# 590                    Mallard                   call    408
# 46                Barn Swallow            flight call    402
# 45                Barn Swallow                   call    346
# 235           Common Sandpiper            flight call    344
# 482          Green-winged Teal                   call    322
# 797     Western Yellow Wagtail            flight call    315
# 546               Little Egret                   call    312

# %%
top_call_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 863 entries, 515 to 862
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   common_name  863 non-null    object
#  1   type         863 non-null    object
#  2   count        863 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 27.0+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the dataframe by 'count' in descending order and select the top 10 rows
top_call_counts = call_distribution_detailed.sort_values(by='count', ascending=False).head(20)

# Set the color palette
sns.set_palette('viridis')

# Plot the data
plt.figure(figsize=(12, 8))

# Add the type of call on top of each bar
for index, row in top_call_counts.iterrows():
    plt.bar(row['common_name'], row['count'])
    plt.text(row['common_name'], row['count'], row['type'], ha='center', va='bottom', rotation=90, color='black')
plt.bar(top_call_counts['common_name'], top_call_counts['count'])
plt.xlabel('Common Name')
plt.ylabel('Count')
plt.title('Top 10 Biggest Counts in Call Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the dataframe by 'count' in descending order and select the top 10 rows
top_call_counts = call_distribution_detailed.sort_values(by='count', ascending=False).head(882)

# Set the color palette
sns.set_palette('viridis')

# Plot the data
plt.figure(figsize=(12, 8))

# Add the type of call on top of each bar
for index, row in top_call_counts.iterrows():
    plt.bar(row['common_name'], row['count'])
plt.bar(top_call_counts['common_name'], top_call_counts['count'])
plt.xlabel('Common Name')
plt.ylabel('Count')
plt.title('Top 10 Biggest Counts in Call Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Sort the dataframe by 'count' in descending order and select the top 20 rows
top_type_counts = call_distribution_detailed.sort_values(by='count', ascending=False).head(882)

# Set the color palette
sns.set_palette('viridis')

# Plot the data
plt.figure(figsize=(12, 8))

# Add the type of call on top of each bar
for index, row in top_type_counts.iterrows():
    plt.bar(row['type'], row['count'])
plt.bar(top_type_counts['type'], top_type_counts['count'])
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Hwat the quack')
plt.xticks(rotation=90)
plt.show()

# %%
# Sort the dataframe by 'count' in descending order and select the top 20 rows
top_type_counts = call_distribution_detailed.sort_values(by='count', ascending=False).head(350)

# Set the color palette
sns.set_palette('viridis')

# Plot the data
plt.figure(figsize=(12, 8))

# Add the type of call on top of each bar
for index, row in top_type_counts.iterrows():
    plt.bar(row['type'], row['count'])
plt.bar(top_type_counts['type'], top_type_counts['count'])
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Biggest Counts in Call Distribution')
plt.xticks(rotation=90)
plt.show()

# %%
common_name_counts = df['common_name'].value_counts().reset_index()
common_name_counts.columns = ['common_name', 'count']
print(common_name_counts)
common_name_counts.head(70)
# Out:
#                    common_name  count
# 0             Common Sandpiper   1305
# 1                House Sparrow   1116
# 2                 Barn Swallow    981
# 3    Black-crowned Night-Heron    888
# 4               Wood Sandpiper    774
# ..                         ...    ...
# 138                 Sooty Tern      1
# 139                Common Myna      1
# 140      Black-crowned Tchagra      1
# 141                  Pied Crow      1
# 142            Pomarine Jaeger      1
#
# [143 rows x 2 columns]
#                   common_name  count
# 0            Common Sandpiper   1305
# 1               House Sparrow   1116
# 2                Barn Swallow    981
# 3   Black-crowned Night-Heron    888
# 4              Wood Sandpiper    774
# ..                        ...    ...
# 65             Egyptian Goose    101
# 66                      Brant    100
# 67            Short-eared Owl     98
# 68               Bank Swallow     86
# 69                Glossy Ibis     83
#
# [70 rows x 2 columns]

# %%
nocturnal_flight_call_count = call_distribution_detailed[call_distribution_detailed['type'] == 'nocturnal flight call']['common_name'].nunique()
print(f"Number of unique common names with 'nocturnal flight call': {nocturnal_flight_call_count}")
# Out:
# Number of unique common names with 'nocturnal flight call': 69

# %%
common_sandpiper_entries = df[df['common_name'] == 'Common Sandpiper']
common_sandpiper_entries.head(20)
# Out:
#      primary_label secondary_labels                               type
# 6364        comsan               []                      [flight call]  \
# 6365        comsan               []                [call, flight call]
# 6366        comsan               []  [female, flight call, male, song]
# 6367        comsan               []                      [flight call]
# 6368        comsan               []                      [flight call]
# 6369        comsan               []                      [flight call]
# 6370        comsan               []          [alarm call, flight call]
# 6371        comsan               []                             [call]
# 6372        comsan               []                             [song]
# 6373        comsan               []                      [flight call]
# 6374        comsan               []                      [flight call]
# 6375        comsan               []                [flight call, song]
# 6376        comsan               []                 [alarm call, call]
# 6377        comsan               []                 [alarm call, call]
# 6378        comsan               []                       [call, song]
# 6379        comsan               []                       [call, song]
# 6380        comsan               []                [call, flight call]
# 6381        comsan       ['arcter']                       [call, song]
# 6382        comsan               []            [alarm and flight call]
# 6383        comsan               []                      [flight call]
#
#       latitude  longitude     scientific_name       common_name date
# 6364   46.4605     6.3914  Actitis hypoleucos  Common Sandpiper  NaN  \
# 6365   68.5350    23.3210  Actitis hypoleucos  Common Sandpiper  NaN
# 6366   52.3527    20.9197  Actitis hypoleucos  Common Sandpiper  NaN
# 6367   43.5848    -1.3987  Actitis hypoleucos  Common Sandpiper  NaN
# 6368   43.4238    -0.4616  Actitis hypoleucos  Common Sandpiper  NaN
# 6369   48.3447    10.9154  Actitis hypoleucos  Common Sandpiper  NaN
# 6370   43.4170    -0.4582  Actitis hypoleucos  Common Sandpiper  NaN
# 6371   60.7689    11.2296  Actitis hypoleucos  Common Sandpiper  NaN
# 6372   60.7757    11.2272  Actitis hypoleucos  Common Sandpiper  NaN
# 6373   51.3480    23.0510  Actitis hypoleucos  Common Sandpiper  NaN
# 6374   41.5048     0.5470  Actitis hypoleucos  Common Sandpiper  NaN
# 6375   68.6501    19.8152  Actitis hypoleucos  Common Sandpiper  NaN
# 6376   61.2885    25.8430  Actitis hypoleucos  Common Sandpiper  NaN
# 6377   62.9683    30.0108  Actitis hypoleucos  Common Sandpiper  NaN
# 6378   45.7825     5.7836  Actitis hypoleucos  Common Sandpiper  NaN
# 6379   60.1162    24.4686  Actitis hypoleucos  Common Sandpiper  NaN
# 6380   51.4148    26.6607  Actitis hypoleucos  Common Sandpiper  NaN
# 6381   64.9834    25.3001  Actitis hypoleucos  Common Sandpiper  NaN
# 6382   65.0667    24.6334  Actitis hypoleucos  Common Sandpiper  NaN
# 6383   37.3533    -5.8855  Actitis hypoleucos  Common Sandpiper  NaN
#
#                  filename                                            license
# 6364  comsan/XC113844.ogg  Creative Commons Attribution-NonCommercial-Sha...  \
# 6365  comsan/XC123893.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6366  comsan/XC129378.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6367  comsan/XC142081.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6368  comsan/XC144768.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6369  comsan/XC146265.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6370  comsan/XC146703.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6371  comsan/XC157141.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6372  comsan/XC157223.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6373  comsan/XC187104.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6374  comsan/XC199825.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6375  comsan/XC210583.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6376  comsan/XC213342.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6377  comsan/XC215171.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6378  comsan/XC237059.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6379  comsan/XC239575.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6380  comsan/XC240497.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6381   comsan/XC25085.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6382   comsan/XC25127.ogg  Creative Commons Attribution-NonCommercial-Sha...
# 6383  comsan/XC268668.ogg  Creative Commons Attribution-NonCommercial-Sha...
#
#       rating   time                 geometry
# 6364     2.5  10:00   POINT (6.3914 46.4605)
# 6365     4.5  05:00    POINT (23.321 68.535)
# 6366     5.0  12:00  POINT (20.9197 52.3527)
# 6367     4.0  07:30  POINT (-1.3987 43.5848)
# 6368     3.0  11:00  POINT (-0.4616 43.4238)
# 6369     4.0  08:30  POINT (10.9154 48.3447)
# 6370     4.0  10:00   POINT (-0.4582 43.417)
# 6371     5.0  10:30  POINT (11.2296 60.7689)
# 6372     5.0  11:00  POINT (11.2272 60.7757)
# 6373     5.0  21:55    POINT (23.051 51.348)
# 6374     3.0  19:00    POINT (0.547 41.5048)
# 6375     4.0  06:00  POINT (19.8152 68.6501)
# 6376     4.5      ?   POINT (25.843 61.2885)
# 6377     5.0  05:00  POINT (30.0108 62.9683)
# 6378     3.5  09:30   POINT (5.7836 45.7825)
# 6379     4.5  17:30  POINT (24.4686 60.1162)
# 6380     4.5  19:00  POINT (26.6607 51.4148)
# 6381     3.5  xx:xx  POINT (25.3001 64.9834)
# 6382     4.5  xx:xx  POINT (24.6334 65.0667)
# 6383     3.0      ?  POINT (-5.8855 37.3533)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Datei laden
file_path = "call_distribution.csv"  # Falls nötig, den korrekten Pfad anpassen
df = pd.read_csv(file_path)

# Die 8 häufigsten Call-Typen bestimmen
top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index
df_filtered = df[df["type"].isin(top_8_calls)]

# Die 10 häufigsten Spezies bestimmen
top_10_species = df.groupby("common_name")["count"].sum().nlargest(10).index

# Spezies-Kategorisierung: Top 10 beibehalten, andere als "Andere" zusammenfassen
df_filtered["common_name"] = df_filtered["common_name"].apply(
    lambda x: x if x in top_10_species else "Andere"
)

# Daten aggregieren
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Logarithmische Skalierung (log1p vermeidet Probleme mit 0-Werten)
df_pivot_log = np.log1p(df_pivot)

# Stacked Bar Chart erstellen
fig, ax = plt.subplots(figsize=(12, 6))
df_pivot_log.plot(kind="bar", stacked=True, colormap="tab10", ax=ax, width=0.8)

# Achsentitel und Labels setzen
ax.set_xlabel("Call Type", fontsize=12)
ax.set_ylabel("Log(Häufigkeit + 1)", fontsize=12)
ax.set_title("Verteilung der Spezies in den 8 häufigsten Call-Typen (log-Skaliert)", fontsize=14)
ax.legend(title="Spezies", bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=8)

# Layout optimieren
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_387541/3691133002.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["common_name"] = df_filtered["common_name"].apply(

# %%
# Die 8 häufigsten Call-Typen bestimmen
top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index

# Datensatz auf diese Call-Typen filtern
df_filtered = df[df["type"].isin(top_8_calls)]

# Die relative Häufigkeit der Spezies innerhalb jedes Call-Typs berechnen
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()

# Pivot-Tabelle für das Stacked Bar Chart
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Umwandlung in relative Häufigkeiten pro Call-Typ
df_pivot_rel = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Datenstruktur prüfen
df_pivot_rel.head()
# Out:
# common_name       African Sacred Ibis  American Tree Sparrow  American Wigeon
# type
# alarm call                   0.000000               0.000000         0.000000  \
# begging call                 0.001634               0.000000         0.000000
# call                         0.000000               0.000322         0.000107
# excitement calls             0.000000               0.000000         0.000000
# flight call                  0.000000               0.000000         0.000000
#
# common_name       Arctic Tern  Bank Swallow  Barn Owl  Barn Swallow
# type
# alarm call           0.030843      0.007539  0.005483      0.038382  \
# begging call         0.011438      0.001634  0.050654      0.039216
# call                 0.008697      0.004187  0.019218      0.037148
# excitement calls     0.000000      0.000000  0.000000      0.000000
# flight call          0.008202      0.006482  0.012965      0.053182
#
# common_name       Belted Kingfisher  Black Francolin  Black Kite  ...
# type                                                              ...
# alarm call                 0.000000         0.000000    0.005483  ...  \
# begging call               0.000000         0.000000    0.022876  ...
# call                       0.000429         0.000215    0.010951  ...
# excitement calls           0.000000         0.000000    0.000000  ...
# flight call                0.000000         0.000000    0.007673  ...
#
# common_name       Western Yellow Wagtail  Whimbrel  Whiskered Tern
# type
# alarm call                      0.013708  0.012337        0.013708  \
# begging call                    0.001634  0.000000        0.024510
# call                            0.026627  0.006120        0.006442
# excitement calls                0.000000  0.000000        0.000000
# flight call                     0.041672  0.013362        0.009525
#
# common_name       White-throated Kingfisher  Wild Turkey  Willow Warbler
# type
# alarm call                         0.000000     0.000000        0.005483  \
# begging call                       0.000000     0.000000        0.011438
# call                               0.000966     0.000215        0.008804
# excitement calls                   0.000000     0.000000        0.000000
# flight call                        0.000265     0.000000        0.000132
#
# common_name       Wilson's Snipe  Wood Duck  Wood Sandpiper  Zitting Cisticola
# type
# alarm call              0.000000   0.000000        0.046607           0.009596
# begging call            0.000000   0.000000        0.000000           0.000000
# call                    0.000107   0.000429        0.018145           0.009448
# excitement calls        0.000000   0.000000        0.000000           0.000000
# flight call             0.000132   0.000132        0.033470           0.008467
#
# [5 rows x 134 columns]

# %%
import matplotlib.pyplot as plt

# Farbschema generieren (Tab10 für hohe Kontraste)
colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))

# Stacked Bar Plot erstellen
fig, ax = plt.subplots(figsize=(12, 6))
df_pivot_rel.plot(kind="bar", stacked=True, colormap="tab10", ax=ax, width=0.8)

# Achsentitel und Labels setzen
ax.set_xlabel("Call Type", fontsize=12)
ax.set_ylabel("Relative Häufigkeit", fontsize=12)
ax.set_title("Verteilung der Spezies in den 8 häufigsten Call-Typen", fontsize=14)
ax.legend(title="Spezies", bbox_to_anchor=(1.05, 1), loc="upper left", fontsize=8)

# Layout optimieren und Plot anzeigen
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_387541/787423229.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))
# /tmp/ipykernel_387541/787423229.py:18: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datei laden
file_path = "call_distribution.csv"  # Falls nötig, den Pfad anpassen
df = pd.read_csv(file_path)

# Die 8 häufigsten Call-Typen bestimmen (nach absoluter Häufigkeit)
top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index
df_filtered = df[df["type"].isin(top_8_calls)]

# Die 10 häufigsten Spezies bestimmen
top_10_species = df.groupby("common_name")["count"].sum().nlargest(10).index

# Spezies-Kategorisierung: Top 10 beibehalten, andere als "Andere" zusammenfassen
df_filtered["common_name"] = df_filtered["common_name"].apply(
    lambda x: x if x in top_10_species else "Andere"
)

# Daten aggregieren
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()

# Pivot-Tabelle für relative Häufigkeiten innerhalb jedes Call-Typs
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Relative Werte berechnen
df_pivot_rel = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Sortierung der Call-Typen nach Gesamthäufigkeit
sorted_types = df_pivot.sum(axis=1).sort_values(ascending=False).index
df_pivot_rel = df_pivot_rel.loc[sorted_types]

# Farben generieren (Tab10 für hohen Kontrast)
colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))
color_map = {species: colors(i) for i, species in enumerate(df_pivot_rel.columns)}

# Pie Charts erstellen
fig, axes = plt.subplots(2, 4, figsize=(18, 10))  # Größere Darstellung
axes = axes.flatten()

for i, call_type in enumerate(df_pivot_rel.index):
    ax = axes[i]
    data = df_pivot_rel.loc[call_type]
    ax.pie(
        data,
        labels=None,  # Labels entfernen, um Überlappungen zu vermeiden
        autopct="%1.1f%%",
        colors=[color_map[species] for species in data.index],
        startangle=140
    )
    ax.set_title(call_type, fontsize=14)

# Legende außerhalb des Plots platzieren
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_map[name], markersize=10) 
           for name in df_pivot_rel.columns]

fig.legend(handles, df_pivot_rel.columns, title="Spezies (common_name)", bbox_to_anchor=(1.05, 0.5), loc="center left", fontsize=12)

# Layout optimieren
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Platz für die Legende lassen
plt.show()
# Out:
# /tmp/ipykernel_387541/1012307572.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["common_name"] = df_filtered["common_name"].apply(
# /tmp/ipykernel_387541/1012307572.py:34: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datei laden
file_path = "call_distribution.csv"  # Falls nötig, den Pfad anpassen
df = pd.read_csv(file_path)

# Die 8 häufigsten Call-Typen bestimmen (nach absoluter Häufigkeit)
top_20_calls = df.groupby("type")["count"].sum().nlargest(20).index
df_filtered = df[df["type"].isin(top_8_calls)]

# Die 10 häufigsten Spezies bestimmen
top_10_species = df.groupby("common_name")["count"].sum().nlargest(10).index

# Spezies-Kategorisierung: Top 10 beibehalten, andere als "Andere" zusammenfassen
df_filtered["common_name"] = df_filtered["common_name"].apply(
    lambda x: x if x in top_10_species else "Andere"
)

# Daten aggregieren
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()

# Pivot-Tabelle für relative Häufigkeiten innerhalb jedes Call-Typs
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Relative Werte berechnen
df_pivot_rel = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Sortierung der Call-Typen nach Gesamthäufigkeit
sorted_types = df_pivot.sum(axis=1).sort_values(ascending=False).index
df_pivot_rel = df_pivot_rel.loc[sorted_types]

# Farben generieren (Tab10 für hohen Kontrast)
colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))
color_map = {species: colors(i) for i, species in enumerate(df_pivot_rel.columns)}

# Pie Charts erstellen
fig, axes = plt.subplots(2, 4, figsize=(18, 10))  # Größere Darstellung
axes = axes.flatten()

for i, call_type in enumerate(df_pivot_rel.index):
    ax = axes[i]
    data = df_pivot_rel.loc[call_type]
    ax.pie(
        data,
        labels=None,  # Labels entfernen, um Überlappungen zu vermeiden
        autopct="%1.1f%%",
        colors=[color_map[species] for species in data.index],
        startangle=140
    )
    ax.set_title(call_type, fontsize=14)

# Legende außerhalb des Plots platzieren
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_map[name], markersize=10) 
           for name in df_pivot_rel.columns]

fig.legend(handles, df_pivot_rel.columns, title="Spezies (common_name)", bbox_to_anchor=(1.05, 0.5), loc="center left", fontsize=12)

# Layout optimieren
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Platz für die Legende lassen
plt.show()
# Out:
# /tmp/ipykernel_387541/579299856.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["common_name"] = df_filtered["common_name"].apply(
# /tmp/ipykernel_387541/579299856.py:34: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datei laden
file_path = "call_distribution.csv"  # Falls nötig, den Pfad anpassen
df = pd.read_csv(file_path)

# Die 8 häufigsten Call-Typen bestimmen (nach absoluter Häufigkeit)
top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index
df_filtered = df[df["type"].isin(top_8_calls)]

# Die 20 häufigsten Spezies bestimmen (statt nur 10)
top_20_species = df.groupby("common_name")["count"].sum().nlargest(20).index

# Spezies-Kategorisierung: Top 20 beibehalten, andere als "Andere" zusammenfassen
df_filtered["common_name"] = df_filtered["common_name"].apply(
    lambda x: x if x in top_20_species else "Andere"
)

# Daten aggregieren
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()

# Pivot-Tabelle für relative Häufigkeiten innerhalb jedes Call-Typs
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Relative Werte berechnen
df_pivot_rel = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Sortierung der Call-Typen nach Gesamthäufigkeit
sorted_types = df_pivot.sum(axis=1).sort_values(ascending=False).index
df_pivot_rel = df_pivot_rel.loc[sorted_types]

# Farben generieren (Tab10 für hohen Kontrast)
colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))
color_map = {species: colors(i) for i, species in enumerate(df_pivot_rel.columns)}

# Pie Charts erstellen
fig, axes = plt.subplots(2, 4, figsize=(18, 10))  # Größere Darstellung
axes = axes.flatten()

for i, call_type in enumerate(df_pivot_rel.index):
    ax = axes[i]
    data = df_pivot_rel.loc[call_type]
    ax.pie(
        data,
        labels=None,  # Labels entfernt, um Überlappungen zu vermeiden
        autopct="%1.1f%%",
        colors=[color_map[species] for species in data.index],
        startangle=140
    )
    ax.set_title(call_type, fontsize=14)

# Legende außerhalb des Plots platzieren
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_map[name], markersize=10) 
           for name in df_pivot_rel.columns]

fig.legend(handles, df_pivot_rel.columns, title="Spezies (common_name)", bbox_to_anchor=(1.05, 0.5), loc="center left", fontsize=12)

# Layout optimieren
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Platz für die Legende lassen
plt.show()
# Out:
# /tmp/ipykernel_387541/1813951682.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["common_name"] = df_filtered["common_name"].apply(
# /tmp/ipykernel_387541/1813951682.py:34: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap("tab10", len(df_pivot_rel.columns))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Datei laden
file_path = "/mnt/data/call_distribution.csv"  # Falls nötig, den Pfad anpassen
df = pd.read_csv(file_path)

# Die 8 häufigsten Call-Typen bestimmen (nach absoluter Häufigkeit)
top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index
df_filtered = df[df["type"].isin(top_8_calls)]

# Alle Spezies beibehalten (keine "Andere"-Kategorie)
all_species = df["common_name"].unique()

# Daten aggregieren
df_grouped = df_filtered.groupby(["type", "common_name"])["count"].sum().reset_index()

# Pivot-Tabelle für relative Häufigkeiten innerhalb jedes Call-Typs
df_pivot = df_grouped.pivot(index="type", columns="common_name", values="count").fillna(0)

# Relative Werte berechnen
df_pivot_rel = df_pivot.div(df_pivot.sum(axis=1), axis=0)

# Sortierung der Call-Typen nach Gesamthäufigkeit
sorted_types = df_pivot.sum(axis=1).sort_values(ascending=False).index
df_pivot_rel = df_pivot_rel.loc[sorted_types]

# Farben generieren (Tab20 für viele verschiedene Farben)
colors = plt.cm.get_cmap("tab20", len(df_pivot_rel.columns))
color_map = {species: colors(i) for i, species in enumerate(df_pivot_rel.columns)}

# Pie Charts erstellen
fig, axes = plt.subplots(2, 4, figsize=(18, 10))  # Größere Darstellung
axes = axes.flatten()

for i, call_type in enumerate(df_pivot_rel.index):
    ax = axes[i]
    data = df_pivot_rel.loc[call_type]
    ax.pie(
        data,
        labels=None,  # Labels entfernt, um Überlappungen zu vermeiden
        autopct="%1.1f%%",
        colors=[color_map[species] for species in data.index],
        startangle=140
    )
    ax.set_title(call_type, fontsize=14)

# Legende außerhalb des Plots platzieren
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color_map[name], markersize=10) 
           for name in df_pivot_rel.columns]

fig.legend(handles, df_pivot_rel.columns, title="Spezies (common_name)", bbox_to_anchor=(1.05, 0.5), loc="center left", fontsize=10)

# Layout optimieren
plt.tight_layout(rect=[0, 0, 0.85, 1])  # Platz für die Legende lassen
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 6
#       4 # Datei laden
#       5 file_path = "/mnt/data/call_distribution.csv"  # Falls nötig, den Pfad anpassen
# ----> 6 df = pd.read_csv(file_path)
#       8 # Die 8 häufigsten Call-Typen bestimmen (nach absoluter Häufigkeit)
#       9 top_8_calls = df.groupby("type")["count"].sum().nlargest(8).index
#
# File ~/Documents/CAPSTONE PROJECT/Ornistone-Project/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/CAPSTONE PROJECT/Ornistone-Project/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Documents/CAPSTONE PROJECT/Ornistone-Project/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/CAPSTONE PROJECT/Ornistone-Project/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Documents/CAPSTONE PROJECT/Ornistone-Project/.venv/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/call_distribution.csv'

# %%
df.head()
# Out:
#   primary_label secondary_labels                    type  latitude  longitude
# 0        amtspa               []                ['call']   55.6237    13.2427  \
# 1        amtspa               []                ['call']   55.6237    13.2427
# 2        amtspa               []                ['call']   55.6237    13.2427
# 3        banswa               []                ['call']   54.5592    11.9695
# 4        banswa               []  ['alarm call', 'call']   46.1374     5.9609
#
#         scientific_name            common_name        date      filename
# 0  Spizelloides arborea  American Tree Sparrow  2016-11-12  XC342444.ogg  \
# 1  Spizelloides arborea  American Tree Sparrow  2016-11-16  XC342952.ogg
# 2  Spizelloides arborea  American Tree Sparrow  2016-11-16  XC342954.ogg
# 3       Riparia riparia           Bank Swallow  2013-06-08  XC138517.ogg
# 4       Riparia riparia           Bank Swallow  2013-07-13  XC142649.ogg
#
#                                              license  rating   time
# 0  Creative Commons Attribution-NonCommercial-Sha...     2.0  14:00  \
# 1  Creative Commons Attribution-NonCommercial-Sha...     3.0  08:31
# 2  Creative Commons Attribution-NonCommercial-Sha...     4.0  10:28
# 3  Creative Commons Attribution-NonCommercial-Sha...     4.0  05:18
# 4  Creative Commons Attribution-NonCommercial-Sha...     3.5  09:00
#
#                   geometry
# 0  POINT (13.2427 55.6237)
# 1  POINT (13.2427 55.6237)
# 2  POINT (13.2427 55.6237)
# 3  POINT (11.9695 54.5592)
# 4   POINT (5.9609 46.1374)

# %%
import pandas as pd

import matplotlib.pyplot as plt

# Convert the 'time' column to datetime format, ignoring NaN values
df['time'] = pd.to_datetime(df['time'], format='%H:%M', errors='coerce')

# Drop rows with NaT values in the 'time' column
df_time_filtered = df.dropna(subset=['time'])

# Extract the hour from the 'time' column
df_time_filtered['hour'] = df_time_filtered['time'].dt.hour

# Plot the distribution of the 'hour' column
plt.figure(figsize=(12, 6))
plt.hist(df_time_filtered['hour'], bins=24, edgecolor='black', alpha=0.7)
plt.xlabel('Hour of the Day')
plt.ylabel('Count')
plt.title('Distribution of Bird Calls by Hour of the Day')
plt.xticks(range(24))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_344518/3101816408.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_time_filtered['hour'] = df_time_filtered['time'].dt.hour
