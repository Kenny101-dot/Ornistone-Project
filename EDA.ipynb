# %% [markdown]
# # Data Exploration, Cleaning, and Preprocessing

# %% [markdown]
# General first look

# %%
import os
import pandas as pd
import numpy as np

# %%
read_csv = pd.read_csv('eBird_Taxonomy_v2021.csv')

# %%
read_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16753 entries, 0 to 16752
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   TAXON_ORDER       16753 non-null  int64
#  1   CATEGORY          16753 non-null  object
#  2   SPECIES_CODE      16753 non-null  object
#  3   PRIMARY_COM_NAME  16753 non-null  object
#  4   SCI_NAME          16753 non-null  object
#  5   ORDER1            16751 non-null  object
#  6   FAMILY            16740 non-null  object
#  7   SPECIES_GROUP     216 non-null    object
#  8   REPORT_AS         3876 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 1.2+ MB

# %%
print(read_csv.columns)
# Out:
# Index(['TAXON_ORDER', 'CATEGORY', 'SPECIES_CODE', 'PRIMARY_COM_NAME',
#        'SCI_NAME', 'ORDER1', 'FAMILY', 'SPECIES_GROUP', 'REPORT_AS'],
#       dtype='object')

# %%
print(read_csv['CATEGORY'].head(10))
# Out:
# 0    species
# 1    species
# 2      slash
# 3    species
# 4    species
# 5       issf
# 6       issf
# 7    species
# 8    species
# 9       issf
# Name: CATEGORY, dtype: object

# %%
print(read_csv['CATEGORY'].unique())
# Out:
# ['species' 'slash' 'issf' 'spuh' 'hybrid' 'domestic' 'form' 'intergrade']

# %%
print(read_csv['ORDER1'].unique())
# Out:
# ['Struthioniformes' 'Rheiformes' 'Tinamiformes' 'Casuariiformes'
#  'Apterygiformes' 'Anseriformes' 'Galliformes' 'Phoenicopteriformes'
#  'Podicipediformes' 'Columbiformes' 'Mesitornithiformes' 'Pterocliformes'
#  'Otidiformes' 'Musophagiformes' 'Cuculiformes' 'Caprimulgiformes'
#  'Opisthocomiformes' 'Gruiformes' 'Charadriiformes' 'Eurypygiformes'
#  'Phaethontiformes' 'Gaviiformes' 'Sphenisciformes' 'Procellariiformes'
#  'Ciconiiformes' 'Suliformes' 'Pelecaniformes' 'Cathartiformes'
#  'Accipitriformes' 'Strigiformes' 'Coliiformes' 'Leptosomiformes'
#  'Trogoniformes' 'Bucerotiformes' 'Coraciiformes' 'Galbuliformes'
#  'Piciformes' 'Cariamiformes' 'Falconiformes' nan 'Psittaciformes'
#  'Passeriformes']

# %%
df = pd.read_csv('train_metadata.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16941 entries, 0 to 16940
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primary_label     16941 non-null  object
#  1   secondary_labels  16941 non-null  object
#  2   type              16941 non-null  object
#  3   latitude          16714 non-null  float64
#  4   longitude         16714 non-null  float64
#  5   scientific_name   16941 non-null  object
#  6   common_name       16941 non-null  object
#  7   author            16941 non-null  object
#  8   license           16941 non-null  object
#  9   rating            16941 non-null  float64
#  10  url               16941 non-null  object
#  11  filename          16941 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.6+ MB

# %%
print(read_csv2['type'].unique())
print(read_csv2['type'].value_counts())
print(read_csv2['type'].value_counts().to_dict())
# Out:
# ["['song']" "['call']" "['call', 'song']"
#  "['adult', 'sex uncertain', 'song']"
#  "['adult', 'call', 'sex uncertain', 'song']" "['']" "['Display call']"
#  "['alarm call']" "['alarm call', 'call']" "['male', 'song']"
#  "['alarm call', 'song']" "['call', 'footsteps', 'wind']"
#  "['call', 'female', 'male']" "['call', 'sex uncertain']"
#  "['adult', 'call', 'sex uncertain']" "['uncertain']"
#  "['adult', 'sex uncertain', 'whistle']" "['adult', 'call', 'song']"
#  "['adult', 'alarm call', 'call', 'sex uncertain', 'song']"
#  "['call', 'flight call']" "['adult', 'flight call', 'sex uncertain']"
#  "['call', 'female', 'flight call', 'male', 'song']"
#  "['adult', 'male', 'song']" "['call', 'male']" "['adult', 'song']"
#  "['adult', 'male', 'sex uncertain', 'song']"
#  "['adult', 'dawn song', 'sex uncertain', 'song']"
#  "['life stage uncertain', 'sex uncertain', 'song']" "['flight call']"
#  "['call', 'duet']" "['adult', 'call']" "['adult', 'flight call']"
# ...

# %%
print(read_csv2['secondary_labels'].nunique())
# Out:
# 751

# %%
df.head(10)
# Out:
#   primary_label secondary_labels                                type
# 0       abethr1               []                            ['song']  \
# 1       abethr1               []                            ['call']
# 2       abethr1               []                            ['song']
# 3       abethr1               []                            ['song']
# 4       abethr1               []                    ['call', 'song']
# 5       abethr1      ['rbsrob1']                            ['song']
# 6       abethr1               []                    ['call', 'song']
# 7       abethr1               []                            ['song']
# 8       abethr1               []                            ['song']
# 9       abethr1               []  ['adult', 'sex uncertain', 'song']
#
#    latitude  longitude     scientific_name               common_name
# 0    4.3906    38.2788  Turdus tephronotus  African Bare-eyed Thrush  \
# ...

# %%
df_filtered = df[df['type'].str.contains("call", case=False, na=False)]

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9430 entries, 1 to 16929
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primary_label     9430 non-null   object
#  1   secondary_labels  9430 non-null   object
#  2   type              9430 non-null   object
#  3   latitude          9236 non-null   float64
#  4   longitude         9236 non-null   float64
#  5   scientific_name   9430 non-null   object
#  6   common_name       9430 non-null   object
#  7   author            9430 non-null   object
#  8   license           9430 non-null   object
#  9   rating            9430 non-null   float64
#  10  url               9430 non-null   object
#  11  filename          9430 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 957.7+ KB

# %%
print(df_filtered['type'].nunique())
# Out:
# 600

# %%
df_filtered.to_csv('only_calls.csv', index=False)

# %%
df2 = pd.read_csv('only_calls.csv')

# %%
df2.head()
# Out:
#   primary_label secondary_labels                                        type
# 0       abethr1               []                                    ['call']  \
# 1       abethr1               []                            ['call', 'song']
# 2       abethr1               []                            ['call', 'song']
# 3       abethr1               []  ['adult', 'call', 'sex uncertain', 'song']
# 4       abhori1      ['combul2']                            ['call', 'song']
#
#    latitude  longitude     scientific_name                  common_name
# 0   -2.9524    38.2921  Turdus tephronotus     African Bare-eyed Thrush  \
# 1   -2.9524    38.2921  Turdus tephronotus     African Bare-eyed Thrush
# 2   -2.9965    37.6244  Turdus tephronotus     African Bare-eyed Thrush
# 3   -2.9858    37.5975  Turdus tephronotus     African Bare-eyed Thrush
# 4  -15.9259    29.0292    Oriolus larvatus  African Black-headed Oriole
#
# ...

# %%
print(df2['common_name'].nunique())
# Out:
# 258

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each common_name
common_name_counts = df['common_name'].value_counts()

# Plot the counts
plt.figure(figsize=(10, 8))
common_name_counts.plot(kind='bar')
plt.title('Count of Different Common Names')
plt.xlabel('Common Name')
plt.ylabel('Count')
plt.show()

# %%
# Count the occurrences of each common_name
common_name_counts = df2['common_name'].value_counts()
common_name_counts.tail(13)
# Out:
# common_name
# Red-and-yellow Barbet    2
# White-crested Turaco     1
# White-browed Crombec     1
# Crested Francolin        1
# Yellow-billed Stork      1
# Mackinnon's Shrike       1
# Parrot-billed Sparrow    1
# Brown-tailed Chat        1
# Goliath Heron            1
# Shelley's Starling       1
# White-headed Sawwing     1
# Long-tailed Cormorant    1
# White-chinned Prinia     1
# Name: count, dtype: int64

# %%
# Count the occurrences of each common_name
common_name_counts = df2['common_name'].value_counts()
#print(common_name_counts)
common_name_counts.head(11)
# Out:
# common_name
# Common Buzzard            425
# Common Sandpiper          412
# Wood Sandpiper            381
# Western Yellow Wagtail    362
# European Bee-eater        350
# Common House-Martin       328
# Barn Swallow              323
# Little Egret              318
# Black Kite                227
# Great Egret               227
# Red-rumped Swallow        178
# Name: count, dtype: int64

# %%
# Filter th common_name_counts for the specific birds
gray_crowned_crane_count = common_name_counts.get('Gray Crowned-Crane', 0)
hindes_pied_babbler_count = common_name_counts.get("Hinde's Pied-Babbler", 0)

print(f"Gray Crowned-Crane count: {gray_crowned_crane_count}")
print(f"Hinde's Pied-Babbler count: {hindes_pied_babbler_count}")
# Out:
# Gray Crowned-Crane count: 6
# Hinde's Pied-Babbler count: 3

# %%
rare_common_names = common_name_counts[common_name_counts >= 99]
#print(rare_common_names.index.tolist())
print(f"Total number of strings which appear 100 or more: {len(rare_common_names)}")
# Out:
# Total number of strings which appear 100 or more: 22

# %%
common_name_counts = df2['type'].value_counts()
print(common_name_counts)
#common_name_counts.tail(13)
# Out:
# type
# ['call']                                                       3987
# ['flight call']                                                1139
# ['call', 'song']                                                527
# ['call', 'flight call']                                         328
# ['adult', 'call', 'sex uncertain']                              289
#                                                                ...
# ['adult', 'call', 'nocturnal flight call', 'sex uncertain']       1
# ['anthropogenic:: rain', 'nocturnal flight call']                 1
# ['adult', 'call', 'duet', 'female', 'male', 'song']               1
# ['call', 'juvenile', 'voice of fledglings']                       1
# ['call', 'display song', 'male', 'song']                          1
# Name: count, Length: 600, dtype: int64

# %%
print(df2['type'].nunique())
# Out:
# 600

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9430 entries, 0 to 9429
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primary_label     9430 non-null   object
#  1   secondary_labels  9430 non-null   object
#  2   type              9430 non-null   object
#  3   latitude          9236 non-null   float64
#  4   longitude         9236 non-null   float64
#  5   scientific_name   9430 non-null   object
#  6   common_name       9430 non-null   object
#  7   author            9430 non-null   object
#  8   license           9430 non-null   object
#  9   rating            9430 non-null   float64
#  10  url               9430 non-null   object
#  11  filename          9430 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 884.2+ KB
